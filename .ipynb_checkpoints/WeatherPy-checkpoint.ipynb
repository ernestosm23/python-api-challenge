# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# !pip install citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")

# cities
# Out:
# Number of cities in the list: 639

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# #Searching though paths to retrive needed values, commenting out after found path
# url = 'http://api.openweathermap.org/data/2.5/weather?'
# units = "metric"
# city_url = f"{url}appid={weather_api_key}&units={units}&q="
# city_weather = requests.get(city_url + city).json()


# city_weather['name']

# %%
# # Set the API base URL
url = 'http://api.openweathermap.org/data/2.5/weather?'
units = "metric"

# Create endpoint URL with each city
city_url = f"{url}appid={weather_api_key}&units={units}&q="


# Define an empty list to fetch the weather data for each city
city_ = []
city_data = []
city_lat = []
city_lng = []
city_max_temp = []
city_humidity = []
city_clouds = []
city_wind = []
city_country = []
city_date = []

# Print to logger
print("Beginning Data Retrieval")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1


#Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_weather = requests.get(city_url + city).json()
        city_.append(city_weather['name'])
        city_lat.append(city_weather['coord']['lat'])
        city_lng.append(city_weather['coord']['lon'])
        city_max_temp.append(city_weather['main']['temp_max'])
        city_humidity.append(city_weather['main']['humidity'])
        city_clouds.append(city_weather['clouds']['all'])
        city_wind.append(city_weather['wind']['speed'])
        city_country.append(city_weather['sys']['country'])
        city_date.append(city_weather['dt'])
        
        
        # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# # Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | mayumba
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | sorland
# Processing Record 5 of Set 1 | geraldton
# Processing Record 6 of Set 1 | esperance
# Processing Record 7 of Set 1 | newton
# Processing Record 8 of Set 1 | dekar
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | chara
# Processing Record 11 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 1 | griffith
# Processing Record 13 of Set 1 | chuy
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | yithion
# City not found. Skipping...
# Processing Record 16 of Set 1 | guerrero negro
# Processing Record 17 of Set 1 | lokosovo
# Processing Record 18 of Set 1 | bengkulu
# Processing Record 19 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 1 | provideniya
# Processing Record 21 of Set 1 | tazmalt
# Processing Record 22 of Set 1 | moose factory
# Processing Record 23 of Set 1 | gigmoto
# Processing Record 24 of Set 1 | okhotsk
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | mount gambier
# Processing Record 28 of Set 1 | dois vizinhos
# Processing Record 29 of Set 1 | thompson
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | talnakh
# Processing Record 33 of Set 1 | huarmey
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 1 | yialos
# City not found. Skipping...
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | baykit
# Processing Record 39 of Set 1 | fort-shevchenko
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | klyuchi
# Processing Record 43 of Set 1 | nanortalik
# Processing Record 44 of Set 1 | ixtapa
# Processing Record 38 of Set 4 | rosarito
# Processing Record 39 of Set 4 | tomatlan
# Processing Record 40 of Set 4 | san cristobal
# Processing Record 41 of Set 4 | khatanga
# Processing Record 42 of Set 4 | nakasongola
# Processing Record 43 of Set 4 | kodiak
# Processing Record 44 of Set 4 | galveston
# Processing Record 45 of Set 4 | chicama
# Processing Record 46 of Set 4 | saint george
# Processing Record 47 of Set 4 | raudeberg
# Processing Record 48 of Set 4 | grand gaube
# Processing Record 49 of Set 4 | eha amufu
# Processing Record 0 of Set 5 | anadyr
# Processing Record 1 of Set 5 | torbay
# Processing Record 2 of Set 5 | lamu
# Processing Record 3 of Set 5 | ponta do sol
# Processing Record 4 of Set 5 | oranjemund
# Processing Record 5 of Set 5 | sakaiminato
# Processing Record 6 of Set 5 | palmerston north
# Processing Record 7 of Set 5 | kavant
# City not found. Skipping...
# Processing Record 8 of Set 5 | castro
# Processing Record 9 of Set 5 | moratuwa
# Processing Record 10 of Set 5 | pevek
# Processing Record 11 of Set 5 | lebu
# Processing Record 12 of Set 5 | yangambi
# Processing Record 13 of Set 5 | manbij
# Processing Record 14 of Set 5 | labuhan
# Processing Record 15 of Set 5 | duliby
# Processing Record 16 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 17 of Set 5 | comodoro rivadavia
# Processing Record 18 of Set 5 | campbell river
# Processing Record 19 of Set 5 | kaitangata
# Processing Record 20 of Set 5 | terrace bay
# Processing Record 21 of Set 5 | kavaratti
# Processing Record 22 of Set 5 | presidencia roque saenz pena
# Processing Record 23 of Set 5 | ilulissat
# Processing Record 24 of Set 5 | praia
# Processing Record 25 of Set 5 | lata
# Processing Record 26 of Set 5 | kasane
# Processing Record 27 of Set 5 | ugra
# Processing Record 28 of Set 5 | butaritari
# Processing Record 29 of Set 5 | den helder
# Processing Record 30 of Set 5 | radece
# Processing Record 31 of Set 5 | zhigansk
# Processing Record 32 of Set 5 | thinadhoo
# Processing Record 33 of Set 5 | college
# Processing Record 34 of Set 5 | bulgan
# Processing Record 35 of Set 5 | ternate
# Processing Record 36 of Set 5 | bonavista
# Processing Record 37 of Set 5 | airai
# Processing Record 38 of Set 5 | bayan
# Processing Record 39 of Set 5 | kaeo
# Processing Record 40 of Set 5 | east london
# Processing Record 41 of Set 5 | luderitz
# Processing Record 42 of Set 5 | divnoye
# Processing Record 43 of Set 5 | nantucket
# Processing Record 44 of Set 5 | weiz
# Processing Record 45 of Set 5 | port hedland
# Processing Record 46 of Set 5 | high level
# Processing Record 47 of Set 5 | conceicao do araguaia
# Processing Record 48 of Set 5 | chamba
# Processing Record 49 of Set 5 | sao filipe
# Processing Record 0 of Set 6 | namatanai
# Processing Record 1 of Set 6 | bambous virieux
# Processing Record 2 of Set 6 | port hardy
# Processing Record 3 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 6 | la romana
# Processing Record 6 of Set 6 | kloulklubed
# Processing Record 7 of Set 6 | saryg-sep
# Processing Record 8 of Set 6 | beyneu
# Processing Record 9 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 6 | rorvik
# Processing Record 11 of Set 6 | mazamari
# Processing Record 12 of Set 6 | narsaq
# Processing Record 13 of Set 6 | milingimbi
# City not found. Skipping...
# Processing Record 14 of Set 6 | harper
# Processing Record 15 of Set 6 | ambon
# Processing Record 16 of Set 6 | salalah
# Processing Record 17 of Set 6 | marienburg
# Processing Record 18 of Set 6 | muros
# Processing Record 19 of Set 6 | redcliffe
# Processing Record 20 of Set 6 | sansepolcro
# Processing Record 21 of Set 6 | caravelas
# Processing Record 22 of Set 6 | majene
# Processing Record 23 of Set 6 | aykhal
# Processing Record 24 of Set 6 | burica
# City not found. Skipping...
# Processing Record 25 of Set 6 | malasila
# Processing Record 26 of Set 6 | yar-sale
# Processing Record 27 of Set 6 | valladolid
# Processing Record 28 of Set 6 | san quintin
# Processing Record 29 of Set 6 | abu kamal
# Processing Record 30 of Set 6 | filadelfia
# Processing Record 31 of Set 6 | uglekamensk
# Processing Record 32 of Set 6 | frederico westphalen
# Processing Record 33 of Set 6 | siirt
# Processing Record 34 of Set 6 | marzuq
# Processing Record 35 of Set 6 | hasaki
# Processing Record 36 of Set 6 | boddam
# Processing Record 37 of Set 6 | santa fe
# Processing Record 38 of Set 6 | ostrovnoy
# Processing Record 39 of Set 6 | honiara
# Processing Record 40 of Set 6 | rosetta
# Processing Record 41 of Set 6 | waipawa
# Processing Record 42 of Set 6 | meulaboh
# Processing Record 43 of Set 6 | san ramon
# Processing Record 44 of Set 6 | fort nelson
# Processing Record 45 of Set 6 | pirai
# Processing Record 46 of Set 6 | maracai
# Processing Record 47 of Set 6 | paamiut
# Processing Record 48 of Set 6 | beldanga
# Processing Record 49 of Set 6 | clyde river
# Processing Record 0 of Set 7 | dickinson
# Processing Record 1 of Set 7 | kampot
# Processing Record 2 of Set 7 | san luis
# Processing Record 3 of Set 7 | asyut
# Processing Record 4 of Set 7 | chapais
# Processing Record 5 of Set 7 | faanui
# Processing Record 6 of Set 7 | manavgat
# Processing Record 7 of Set 7 | zaporizhzhya
# Processing Record 8 of Set 7 | victoria
# Processing Record 9 of Set 7 | devyatka
# City not found. Skipping...
# Processing Record 10 of Set 7 | port shepstone
# Processing Record 11 of Set 7 | corumba
# Processing Record 12 of Set 7 | bethel
# Processing Record 13 of Set 7 | novoagansk
# Processing Record 14 of Set 7 | gamba
# Processing Record 15 of Set 7 | qingdao
# Processing Record 16 of Set 7 | camacha
# Processing Record 17 of Set 7 | lubao
# Processing Record 18 of Set 7 | egvekinot
# Processing Record 19 of Set 7 | ugoofaaru
# Processing Record 20 of Set 7 | eureka
# Processing Record 21 of Set 7 | opelousas
# Processing Record 22 of Set 7 | esso
# Processing Record 23 of Set 7 | longjiang
# Processing Record 9 of Set 10 | zhovti vody
# Processing Record 10 of Set 10 | yulara
# Processing Record 11 of Set 10 | tabuk
# Processing Record 12 of Set 10 | amuntai
# Processing Record 13 of Set 10 | samfya
# Processing Record 14 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 10 | nuevitas
# Processing Record 16 of Set 10 | padang
# Processing Record 17 of Set 10 | akyab
# Processing Record 18 of Set 10 | kudahuvadhoo
# Processing Record 19 of Set 10 | lae
# Processing Record 20 of Set 10 | flinders
# Processing Record 21 of Set 10 | lithakia
# Processing Record 22 of Set 10 | west fargo
# Processing Record 23 of Set 10 | ngunguru
# Processing Record 24 of Set 10 | xuddur
# Processing Record 25 of Set 10 | paraiso
# Processing Record 26 of Set 10 | piacabucu
# Processing Record 27 of Set 10 | yanam
# Processing Record 28 of Set 10 | upata
# Processing Record 29 of Set 10 | bairiki
# Processing Record 30 of Set 10 | mehamn
# Processing Record 31 of Set 10 | zhangjiakou
# Processing Record 32 of Set 10 | shakawe
# Processing Record 33 of Set 10 | yerbogachen
# Processing Record 34 of Set 10 | simpang
# Processing Record 35 of Set 10 | itarantim
# Processing Record 36 of Set 10 | maxixe
# Processing Record 37 of Set 10 | kashi
# Processing Record 38 of Set 10 | hailar
# Processing Record 39 of Set 10 | amapa
# Processing Record 40 of Set 10 | andenes
# Processing Record 41 of Set 10 | dukat
# Processing Record 42 of Set 10 | natal
# Processing Record 43 of Set 10 | elk city
# Processing Record 44 of Set 10 | livingston
# Processing Record 45 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 10 | jasper
# Processing Record 47 of Set 10 | tarakan
# Processing Record 48 of Set 10 | mesyagutovo
# Processing Record 49 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 0 of Set 11 | clermont
# Processing Record 1 of Set 11 | garowe
# Processing Record 2 of Set 11 | hualmay
# Processing Record 3 of Set 11 | deshna
# City not found. Skipping...
# Processing Record 4 of Set 11 | mounana
# Processing Record 5 of Set 11 | luanda
# Processing Record 6 of Set 11 | sayyan
# Processing Record 7 of Set 11 | miri
# Processing Record 8 of Set 11 | altay
# Processing Record 9 of Set 11 | kos
# Processing Record 10 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 11 of Set 11 | murmashi
# Processing Record 12 of Set 11 | tsiroanomandidy
# Processing Record 13 of Set 11 | sicamous
# Processing Record 14 of Set 11 | coihaique
# Processing Record 15 of Set 11 | vilhena
# Processing Record 16 of Set 11 | coos bay
# Processing Record 17 of Set 11 | magdagachi
# Processing Record 18 of Set 11 | powell
# Processing Record 19 of Set 11 | ban tak
# Processing Record 20 of Set 11 | valparaiso
# Processing Record 21 of Set 11 | cascais
# Processing Record 22 of Set 11 | kawalu
# Processing Record 23 of Set 11 | obo
# Processing Record 24 of Set 11 | tupik
# Processing Record 25 of Set 11 | madang
# Processing Record 26 of Set 11 | kothi
# Processing Record 27 of Set 11 | kirensk
# Processing Record 28 of Set 11 | panjwin
# City not found. Skipping...
# Processing Record 29 of Set 11 | uruacu
# Processing Record 30 of Set 11 | samana
# Processing Record 31 of Set 11 | sann
# Processing Record 32 of Set 11 | sitka
# Processing Record 33 of Set 11 | lisakovsk
# Processing Record 34 of Set 11 | mongomo
# Processing Record 35 of Set 11 | zelenoborskiy
# Processing Record 36 of Set 11 | juxtlahuaca
# Processing Record 37 of Set 11 | yarim
# Processing Record 38 of Set 11 | grand-lahou
# Processing Record 39 of Set 11 | rio muerto
# Processing Record 40 of Set 11 | karaton
# Processing Record 41 of Set 11 | gamboma
# Processing Record 42 of Set 11 | inirida
# Processing Record 43 of Set 11 | takoradi
# Processing Record 44 of Set 11 | susanville
# Processing Record 45 of Set 11 | bratsk
# Processing Record 46 of Set 11 | waingapu
# Processing Record 47 of Set 11 | cumpas
# Processing Record 48 of Set 11 | innisfail
# Processing Record 49 of Set 11 | srivardhan
# Processing Record 0 of Set 12 | willowmore
# Processing Record 1 of Set 12 | mayo
# Processing Record 2 of Set 12 | chimbote
# Processing Record 3 of Set 12 | nizhniy tsasuchey
# Processing Record 4 of Set 12 | ulagan
# Processing Record 5 of Set 12 | talaya
# Processing Record 6 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 7 of Set 12 | key west
# Processing Record 8 of Set 12 | amahai
# Processing Record 9 of Set 12 | vao
# Processing Record 10 of Set 12 | serenje
# Processing Record 11 of Set 12 | marshall
# Processing Record 12 of Set 12 | karratha
# Processing Record 13 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 14 of Set 12 | barcelos
# Processing Record 15 of Set 12 | port blair
# Processing Record 16 of Set 12 | saint-augustin
# Processing Record 17 of Set 12 | pastavy
# Processing Record 18 of Set 12 | barranca
# Processing Record 19 of Set 12 | emmendingen
# Processing Record 20 of Set 12 | sur
# Processing Record 21 of Set 12 | tungor
# Processing Record 22 of Set 12 | saskylakh
# Processing Record 23 of Set 12 | avigliana
# Processing Record 24 of Set 12 | san jose
# Processing Record 25 of Set 12 | castlegar
# Processing Record 26 of Set 12 | porto empedocle
# Processing Record 27 of Set 12 | ballina
# Processing Record 28 of Set 12 | fairbanks
# Processing Record 29 of Set 12 | creel
# Processing Record 30 of Set 12 | birao
# Processing Record 31 of Set 12 | lethem
# Processing Record 32 of Set 12 | gilbues
# Processing Record 33 of Set 12 | arden
# Processing Record 34 of Set 12 | yicheng
# Processing Record 35 of Set 12 | shetpe
# Processing Record 36 of Set 12 | bosaso
# Processing Record 37 of Set 12 | whitecourt
# Processing Record 38 of Set 12 | winneba
# Processing Record 39 of Set 12 | arklow
# Processing Record 40 of Set 12 | ust-nera
# Processing Record 41 of Set 12 | kandrian
# Processing Record 42 of Set 12 | praia da vitoria
# Processing Record 43 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 44 of Set 12 | ayer itam
# City not found. Skipping...
# Processing Record 45 of Set 12 | songjianghe
# Processing Record 46 of Set 12 | lyubim
# Processing Record 47 of Set 12 | saveh
# Processing Record 48 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 12 | isangel
# Processing Record 0 of Set 13 | marsh harbour
# Processing Record 1 of Set 13 | abnub
# Processing Record 2 of Set 13 | faya
# Processing Record 3 of Set 13 | bodaybo
# Processing Record 4 of Set 13 | qui nhon
# Processing Record 5 of Set 13 | erenhot
# Processing Record 6 of Set 13 | cullera
# Processing Record 7 of Set 13 | turbat
# Processing Record 8 of Set 13 | luancheng
# Processing Record 9 of Set 13 | liverpool
# Processing Record 10 of Set 13 | cabedelo
# Processing Record 11 of Set 13 | dali
# Processing Record 12 of Set 13 | novoplatnirovskaya
# Processing Record 13 of Set 13 | pimentel
# Processing Record 14 of Set 13 | fortuna foothills
# Processing Record 15 of Set 13 | kasulu
# Processing Record 16 of Set 13 | manicore
# Processing Record 17 of Set 13 | mahajanga
# Processing Record 18 of Set 13 | partizanskoye
# Processing Record 19 of Set 13 | saint-francois
# Processing Record 20 of Set 13 | aleksandrov gay
# Processing Record 21 of Set 13 | male
# Processing Record 22 of Set 13 | ahipara
# Processing Record 23 of Set 13 | arlit
# Processing Record 24 of Set 13 | moussoro
# Processing Record 25 of Set 13 | gorontalo
# Processing Record 26 of Set 13 | kamiiso
# Processing Record 27 of Set 13 | oksovskiy
# Processing Record 28 of Set 13 | iracoubo
# Processing Record 29 of Set 13 | gumusyaka
# City not found. Skipping...
# Processing Record 30 of Set 13 | shitanjing
# Processing Record 31 of Set 13 | holsted
# Processing Record 32 of Set 13 | sangmelima
# Processing Record 33 of Set 13 | tingo maria
# Processing Record 34 of Set 13 | udachnyy
# Processing Record 35 of Set 13 | dhule
# Processing Record 36 of Set 13 | zabid
# Processing Record 37 of Set 13 | scarborough
# Processing Record 38 of Set 13 | tolmachevo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data = ({"City": city_, "Lat": city_lat, "Lng": city_lng, "Max Temp": city_max_temp,
              "Humidity": city_humidity, "Cloudiness": city_clouds, "Wind Speed": city_wind,
              "Country": city_country, "Date": city_date})

city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          593
# Lat           593
# Lng           593
# Max Temp      593
# Humidity      593
# Cloudiness    593
# Wind Speed    593
# Country       593
# Date          593
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Albany  42.6001  -73.9662     28.27        44         100        2.24
# 1    Mayumba  -3.4320   10.6554     26.40        84          60        2.18
# 2     Dikson  73.5069   80.5464    -18.28       100         100        4.31
# 3    Sørland  67.6670   12.6934      6.92        86         100        3.68
# 4  Geraldton -28.7667  114.6000     10.23        93           0        2.57
#
#   Country        Date
# 0      US  1681586846
# 1      GA  1681587003
# 2      RU  1681587005
# 3      NO  1681587006
# 4      AU  1681587006

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           Albany  42.6001  -73.9662     28.27        44         100
# 1          Mayumba  -3.4320   10.6554     26.40        84          60
# 2           Dikson  73.5069   80.5464    -18.28       100         100
# 3          Sørland  67.6670   12.6934      6.92        86         100
# 4        Geraldton -28.7667  114.6000     10.23        93           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.24      US  1681586846
# 1              2.18      GA  1681587003
# 2              4.31      RU  1681587005
# 3              3.68      NO  1681587006
# 4              2.57      AU  1681587006

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
latitude = city_data_df["Lat"]
temp = city_data_df["Max Temp"]

# Incorporate the other graph properties
plt. scatter(latitude, temp, marker = 'o', color = 'b', alpha = .70)
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title("Temperature vs. Latitude")

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
temp = city_data_df["Humidity"]

# Incorporate the other graph properties
plt. scatter(latitude, temp, marker = 'o', color = 'b', alpha = .70)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Temperature vs. Humidity")

# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
temp = city_data_df["Cloudiness"]

# Incorporate the other graph properties
plt. scatter(latitude, temp, marker = 'o', color = 'b', alpha = .70)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Temperature vs. Cloudiness")

# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
temp = city_data_df["Wind Speed"]

# Incorporate the other graph properties
plt. scatter(latitude, temp, marker = 'o', color = 'b', alpha = .70)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Temperature vs. Wind Speed")

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
from scipy import stats

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = pd.DataFrame(city_data_df.loc[(city_data_df["Lat"] >= 0)])

# Display sample data
northern_hemi_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         Albany  42.6001  -73.9662     28.27        44         100
# 2         Dikson  73.5069   80.5464    -18.28       100         100
# 3        Sørland  67.6670   12.6934      6.92        86         100
# 6         Newton  42.3370  -71.2092     27.09        54          40
# 9          Chara  56.9064  118.2631     -7.12        83         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.24      US  1681586846
# 2              4.31      RU  1681587005
# 3              3.68      NO  1681587006
# 6              5.66      US  1681587007
# 9              0.61      RU  1681587012

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = pd.DataFrame(city_data_df.loc[(city_data_df["Lat"] < 0)])

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          Mayumba  -3.4320   10.6554     26.40        84          60
# 4        Geraldton -28.7667  114.6000     10.23        93           0
# 5        Esperance -33.8667  121.9000     17.02        77         100
# 7            Dekar -21.5333   21.9333     22.79        28          32
# 8          Ushuaia -54.8000  -68.3000      7.79        70           0
#
#          Wind Speed Country        Date
# City_ID
# 1              2.18      GA  1681587003
# 4              2.57      AU  1681587006
# 5              8.09      AU  1681587007
# 7              3.44      BW  1681587011
# 8              1.54      AR  1681587012

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(5,1),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = -0.6x +35.84
# The r-value is: 0.720654253267304

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq2 = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq2)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq2,(-30,10),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.33x +28.74
# The r-value is: 0.5770765572651645

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']


# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq2 = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq2)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq2,(50,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.24x +59.17
# The r-value is: 0.04479569590112157

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']


# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq2 = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq2)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq2,(-50,30),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.33x +82.96
# The r-value is: 0.06850690259507802

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']


# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq2 = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq2)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq2,(50,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.18x +52.95
# The r-value is: 0.008014863445255644

# %%
# Southern Hemisphere
# Linear regression on Northern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']


# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq2 = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq2)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq2,(50,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.93x +84.47
# The r-value is: 0.1026615166978466

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']


# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq2 = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq2)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq2,(10,11),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.01x +3.25
# The r-value is: 0.003460653072067206

# %%
# Southern Hemisphere
# Linear regression on Northern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']


# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq2 = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq2)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq2,(10,11),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = -0.03x +2.48
# The r-value is: 0.03516667867532065

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
